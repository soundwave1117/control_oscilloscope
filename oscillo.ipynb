# %%
import pyvisa
import matplotlib.pyplot as plt
import numpy as np
from tek7k import tek7k
from maekawa import stage

# %%
rm = pyvisa.ResourceManager()
visa_list = rm.list_resources()
visa_list
# Out:
# ('TCPIP0::TEKSCOPE-536165::inst0::INSTR',
#  'TCPIP0::172.20.147.149::inst0::INSTR',
#  'GPIB0::10::INSTR',
#  'GPIB0::2::INSTR',
#  'GPIB0::8::INSTR',
#  'USB0::0x1313::0x8078::P0021527::0::INSTR')

# %%
scope = tek7k.Scope(visa_list[1])#オシロスコープの接続先指定
scope.average(600)#averaging回数指定
# Out:
# 30

# %%
time,wave = scope.fetch(1)#時間、電圧波形取得()内に取得するチャンネル名取得
plt.plot(time,wave)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-22c33e2c6113> in <module>
# ----> 1 stage.to_zero()
#
# AttributeError: module 'maekawa.stage' has no attribute 'to_zero'
